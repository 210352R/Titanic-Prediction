# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)

# %%
df=pd.read_csv("train.csv");
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df2 = df.drop('Name', axis=1)

# %%
sns.boxplot(x = df2["Fare"])
# Out:
# <Axes: xlabel='Fare'>

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Add Mean value to Age Column
from sklearn.impute import SimpleImputer
my_imputer = SimpleImputer()

# %%
# df2 = df2[df2["Fare"] <= 320]

# %%
# Make X and Y
Y = df2['Survived']
X = df2.drop('Survived',axis=1)

# %%
Y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
X.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0            1       3    male  22.0      1      0         A/5 21171   7.2500
# 1            2       1  female  38.0      1      0          PC 17599  71.2833
# 2            3       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3            4       1  female  35.0      1      0            113803  53.1000
# 4            5       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C
# 2   NaN        S
# 3  C123        S
# 4   NaN        S

# %%
X_2 = X.drop("PassengerId",axis=1)

# %%
X_2.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       1  female  35.0      1      0            113803  53.1000  C123
# 4       3    male  35.0      0      0            373450   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
# def plotFeatures ():

# %%
# prompt: remove rows that Fare greater than 320

# %%
# prompt: give function for plot scatter plots
def plotScatter (X,Y):
    for i, column in enumerate(X.columns):

        plt.figure(i)
        plt.figure(figsize=(8, 6))
        plt.scatter(X[column], Y)
        plt.xlabel(column)
        plt.ylabel('Survived')

# %%
X_2.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
X_2.shape
# Out:
# (891, 9)

# %%
X_2 = X_2.drop('Cabin',axis=1)

# %%
X_2.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# 0       3    male  22.0      1      0         A/5 21171   7.2500        S
# 1       1  female  38.0      1      0          PC 17599  71.2833        C
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250        S
# 3       1  female  35.0      1      0            113803  53.1000        S
# 4       3    male  35.0      0      0            373450   8.0500        S

# %%
X_2.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Embarked      2
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# Create the imputer object with the desired strategy
imputer = SimpleImputer(strategy='most_frequent')

# Fit the imputer object to the data
imputer.fit(X_2['Embarked'].values.reshape(-1, 1))

# Transform the data, replacing missing values with the most frequent value
X_2['Embarked'] = imputer.transform(X_2['Embarked'].values.reshape(-1, 1))

# %%
unique_values = X_2['Embarked'].unique()
unique_values
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_2, Y, test_size=0.2, random_state=10)

# %%
X_train.head()
# Out:
#      Pclass     Sex   Age  SibSp  Parch  Ticket     Fare Embarked
# 57        3    male  28.5      0      0    2697   7.2292        C
# 717       2  female  27.0      0      0   34218  10.5000        S
# 431       3  female   NaN      1      0  376564  16.1000        S
# 633       1    male   NaN      0      0  112052   0.0000        S
# 163       3    male  17.0      0      0  315093   8.6625        S

# %%
# prompt: i need a seaborn barplot categorizing the countOf("Survived") with the sex
plt.figure(figsize=(8, 6))
sns.countplot(df2 , x="Sex" , hue="Survived")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
# Create the imputer object with the desired strategy
imputer = SimpleImputer(strategy='mean')

# Fit the imputer object to the data
imputer.fit(X_train['Age'].values.reshape(-1, 1))

# Transform the data, replacing missing values with the most frequent value
X_train['Age'] = imputer.transform(X_train['Age'].values.reshape(-1, 1))

# %%
# Create the imputer object with the desired strategy
imputer = SimpleImputer(strategy='mean')

# Fit the imputer object to the data
imputer.fit(X_test['Age'].values.reshape(-1, 1))

# Transform the data, replacing missing values with the most frequent value
X_test['Age'] = imputer.transform(X_test['Age'].values.reshape(-1, 1))
X_test.head()
# Out:
#      Pclass     Sex   Age  SibSp  Parch              Ticket      Fare Embarked
# 590       3    male  35.0      0      0   STON/O 2. 3101273    7.1250        S
# 131       3    male  20.0      0      0  SOTON/O.Q. 3101307    7.0500        S
# 628       3    male  26.0      0      0              349224    7.8958        S
# 195       1  female  58.0      0      0            PC 17569  146.5208        C
# 230       1  female  35.0      1      0               36973   83.4750        S

# %%
X_train.head()
# Out:
#      Pclass     Sex        Age  SibSp  Parch  Ticket     Fare Embarked
# 57        3    male  28.500000      0      0    2697   7.2292        C
# 717       2  female  27.000000      0      0   34218  10.5000        S
# 431       3  female  29.668544      1      0  376564  16.1000        S
# 633       1    male  29.668544      0      0  112052   0.0000        S
# 163       3    male  17.000000      0      0  315093   8.6625        S

# %%
X_train = pd.get_dummies(X_train, columns=['Embarked'], prefix=['Embarked'])
X_train.head()
# Out:
#      Pclass     Sex        Age  SibSp  Parch  Ticket     Fare  Embarked_C  \
# 57        3    male  28.500000      0      0    2697   7.2292           1
# 717       2  female  27.000000      0      0   34218  10.5000           0
# 431       3  female  29.668544      1      0  376564  16.1000           0
# 633       1    male  29.668544      0      0  112052   0.0000           0
# 163       3    male  17.000000      0      0  315093   8.6625           0
#
#      Embarked_Q  Embarked_S
# 57            0           0
# 717           0           1
# 431           0           1
# 633           0           1
# 163           0           1

# %%
# prompt: In 'Sex' set 1 to male and set '0' to female

X_train['Sex'] = [1 if i == 'male' else 0 for i in X_train['Sex']]

# %%
X_train.head()
# Out:
#      Pclass  Sex        Age  SibSp  Parch  Ticket     Fare  Embarked_C  \
# 57        3    1  28.500000      0      0    2697   7.2292           1
# 717       2    0  27.000000      0      0   34218  10.5000           0
# 431       3    0  29.668544      1      0  376564  16.1000           0
# 633       1    1  29.668544      0      0  112052   0.0000           0
# 163       3    1  17.000000      0      0  315093   8.6625           0
#
#      Embarked_Q  Embarked_S
# 57            0           0
# 717           0           1
# 431           0           1
# 633           0           1
# 163           0           1

# %%
# if X_test['Embarked'].dtype == 'object':
#        X_test = pd.get_dummies(X_test, columns=['Embarked'], prefix=['Embarked'])

# %%
X_test['Sex'] = [1 if i == 'male' else 0 for i in X_test['Sex']]
X_test.head()
# Out:
#      Pclass  Sex   Age  SibSp  Parch              Ticket      Fare Embarked
# 590       3    1  35.0      0      0   STON/O 2. 3101273    7.1250        S
# 131       3    1  20.0      0      0  SOTON/O.Q. 3101307    7.0500        S
# 628       3    1  26.0      0      0              349224    7.8958        S
# 195       1    0  58.0      0      0            PC 17569  146.5208        C
# 230       1    0  35.0      1      0               36973   83.4750        S

# %%
X_test.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
X_train  = X_train.drop("Ticket", axis=1)

# %%
X_train.head()
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked_C  Embarked_Q  \
# 57        3    1  28.500000      0      0   7.2292           1           0
# 717       2    0  27.000000      0      0  10.5000           0           0
# 431       3    0  29.668544      1      0  16.1000           0           0
# 633       1    1  29.668544      0      0   0.0000           0           0
# 163       3    1  17.000000      0      0   8.6625           0           0
#
#      Embarked_S
# 57            0
# 717           1
# 431           1
# 633           1
# 163           1

# %%
X_test = X_test.drop("Ticket", axis=1)

# %% [markdown]
# ### Build Model -----------

# %%
from xgboost import XGBClassifier

my_model = XGBClassifier(n_estimators=2500, learning_rate=0.025)
my_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.025, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=2500, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
X_test = pd.get_dummies(X_test, columns=['Embarked'], prefix=['Embarked'])
X_test.head()
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Embarked_C  Embarked_Q  \
# 590       3    1  35.0      0      0    7.1250           0           0
# 131       3    1  20.0      0      0    7.0500           0           0
# 628       3    1  26.0      0      0    7.8958           0           0
# 195       1    0  58.0      0      0  146.5208           1           0
# 230       1    0  35.0      1      0   83.4750           0           0
#
#      Embarked_S
# 590           1
# 131           1
# 628           1
# 195           0
# 230           1

# %%
# prompt: measure accuracy score

from sklearn.metrics import accuracy_score
y_pred = my_model.predict(X_test)

# Convert prediction to binary values
y_pred_binary = [int(round(p)) for p in y_pred]

# Calculate and print the accuracy score
accuracy = accuracy_score(y_test, y_pred_binary)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8324022346368715

# %%
def train_models(estimators,learning_rates):
  results = []
  for estimator in estimators:
      for learning_rate in learning_rates:
          # Initialize XGBoost Classifier
          model = XGBClassifier(n_estimators=estimator, learning_rate=learning_rate, random_state=42)

          # Train the model
          model.fit(X_train, y_train)

          # Make predictions
          y_pred = model.predict(X_test)

          # Evaluate the model
          accuracy = accuracy_score(y_test, y_pred)

          # Store the results
          results.append({
              'estimators': estimator,
              'learning_rate': learning_rate,
              'accuracy': accuracy
          })

  return results

# %%
estimators = [500, 1000, 1500, 1750,2000,2250,2500, 3000,3250,3500,4000]
learning_rates = [0.05,  0.03 , 0.025, 0.0225 , 0.018 ,0.015 , 0.005]
res = train_models(estimators,learning_rates)

# %%
print(res)
# Out:
# [{'estimators': 500, 'learning_rate': 0.05, 'accuracy': 0.8379888268156425}, {'estimators': 500, 'learning_rate': 0.03, 'accuracy': 0.8324022346368715}, {'estimators': 500, 'learning_rate': 0.025, 'accuracy': 0.8435754189944135}, {'estimators': 500, 'learning_rate': 0.0225, 'accuracy': 0.8547486033519553}, {'estimators': 500, 'learning_rate': 0.018, 'accuracy': 0.8547486033519553}, {'estimators': 500, 'learning_rate': 0.015, 'accuracy': 0.8659217877094972}, {'estimators': 500, 'learning_rate': 0.005, 'accuracy': 0.8491620111731844}, {'estimators': 1000, 'learning_rate': 0.05, 'accuracy': 0.8324022346368715}, {'estimators': 1000, 'learning_rate': 0.03, 'accuracy': 0.8268156424581006}, {'estimators': 1000, 'learning_rate': 0.025, 'accuracy': 0.8212290502793296}, {'estimators': 1000, 'learning_rate': 0.0225, 'accuracy': 0.8379888268156425}, {'estimators': 1000, 'learning_rate': 0.018, 'accuracy': 0.8435754189944135}, {'estimators': 1000, 'learning_rate': 0.015, 'accuracy': 0.84357541899
# ...

# %%
# prompt: get maximum accuracy of res

max_accuracy = max(res, key=lambda x: x['accuracy'])['accuracy']
print(f"Maximum accuracy: {max_accuracy}")
# Out:
# Maximum accuracy: 0.8715083798882681

# %%
# prompt: get esimater and learning rate of maximum Accuracy

max_accuracy = max(res, key=lambda x: x['accuracy'])
print(max_accuracy)
# Out:
# {'estimators': 1500, 'learning_rate': 0.005, 'accuracy': 0.8715083798882681}

# %%
#For XGBOOST Best Hyperparameter
best_asst = max_accuracy['estimators']
best_learning_rate = max_accuracy['learning_rate']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train[['Age', 'Fare']] = scaler.fit_transform(X_train[['Age', 'Fare']])
X_test[['Age', 'Fare']] = scaler.transform(X_test[['Age', 'Fare']])

X_train.head()
# Out:
#      Pclass  Sex           Age  SibSp  Parch      Fare  Embarked_C  \
# 57        3    1 -9.004756e-02      0      0 -0.496598           1
# 717       2    0 -2.056370e-01      0      0 -0.433020           0
# 431       3    0  2.737707e-16      1      0 -0.324167           0
# 633       1    1  2.737707e-16      0      0 -0.637119           0
# 163       3    1 -9.762331e-01      0      0 -0.468737           0
#
#      Embarked_Q  Embarked_S
# 57            0           0
# 717           0           1
# 431           0           1
# 633           0           1
# 163           0           1

# %%
my_model = XGBClassifier(n_estimators=best_asst, learning_rate=best_learning_rate)
my_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.005, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1500, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
from sklearn.metrics import accuracy_score
y_pred = my_model.predict(X_test)

# Convert prediction to binary values
y_pred_binary = [int(round(p)) for p in y_pred]

# Calculate and print the accuracy score
accuracy = accuracy_score(y_test, y_pred_binary)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8100558659217877

# %%
def train_models(estimators,learning_rates):
  results = []
  for estimator in estimators:
      for learning_rate in learning_rates:
          # Initialize XGBoost Classifier
          model = XGBClassifier(n_estimators=estimator, learning_rate=learning_rate, random_state=42)

          # Train the model
          model.fit(X_train, y_train)

          # Make predictions
          y_pred = model.predict(X_test)

          # Evaluate the model
          accuracy = accuracy_score(y_test, y_pred)

          # Store the results
          results.append({
              'estimators': estimator,
              'learning_rate': learning_rate,
              'accuracy': accuracy
          })

  return results

estimators = [500, 1000, 1500, 1750,2000,2250,2500, 3000,3250,3500,4000]
learning_rates = [0.05,  0.03 , 0.025, 0.0225 , 0.018 ,0.015 , 0.005]
res = train_models(estimators,learning_rates)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-345-27c1868f0ef8> in <cell line: 29>()
#      27 learning_rates = [0.05,  0.03 , 0.025, 0.0225 , 0.018 ,0.015 , 0.005]
#      28 res = train_models(estimators,learning_rates)
# ---> 29 prinrt(res)
#      30
#      31
#
# NameError: name 'prinrt' is not defined

# %%
print(res)
# Out:
# [{'estimators': 500, 'learning_rate': 0.05, 'accuracy': 0.8379888268156425}, {'estimators': 500, 'learning_rate': 0.03, 'accuracy': 0.8324022346368715}, {'estimators': 500, 'learning_rate': 0.025, 'accuracy': 0.8435754189944135}, {'estimators': 500, 'learning_rate': 0.0225, 'accuracy': 0.8547486033519553}, {'estimators': 500, 'learning_rate': 0.018, 'accuracy': 0.8547486033519553}, {'estimators': 500, 'learning_rate': 0.015, 'accuracy': 0.8659217877094972}, {'estimators': 500, 'learning_rate': 0.005, 'accuracy': 0.8491620111731844}, {'estimators': 1000, 'learning_rate': 0.05, 'accuracy': 0.8324022346368715}, {'estimators': 1000, 'learning_rate': 0.03, 'accuracy': 0.8268156424581006}, {'estimators': 1000, 'learning_rate': 0.025, 'accuracy': 0.8212290502793296}, {'estimators': 1000, 'learning_rate': 0.0225, 'accuracy': 0.8379888268156425}, {'estimators': 1000, 'learning_rate': 0.018, 'accuracy': 0.8435754189944135}, {'estimators': 1000, 'learning_rate': 0.015, 'accuracy': 0.84357541899
# ...

# %%
max_accuracy = max(res, key=lambda x: x['accuracy'])
print(max_accuracy)
# Out:
# {'estimators': 1500, 'learning_rate': 0.005, 'accuracy': 0.8715083798882681}

# %%
###################################################################################################################


#####################################################################################################################

# %% [markdown]
# ## Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split



# Define the parameter grid for each model
logistic_params = {'C': [0.001, 0.01, 0.1, 1, 10, 100]}  # Regularization parameter
random_forest_params = {'n_estimators': [10, 50,51,52,55,56,57,58,59,60,61,62,65, 100],  # Number of trees
                        'max_depth': [None, 10, 20, 30]}       # Maximum depth of trees

# Create a dictionary with models and their respective parameter grids
models = {'Logistic Regression': (LogisticRegression(), logistic_params),
          'Random Forest': (RandomForestClassifier(), random_forest_params)}

# Perform GridSearchCV for each model
for model_name, (model, param_grid) in models.items():
    print(f"Performing GridSearchCV for {model_name}")
    grid_search = GridSearchCV(model, param_grid, cv=5, scoring='accuracy')
    grid_search.fit(X_train, y_train)

    print(f"Best parameters for {model_name}: {grid_search.best_params_}")
    print(f"Best cross-validation score for {model_name}: {grid_search.best_score_}")
    print()

# Note: You can add more models and their respective parameter grids to the 'models' dictionary if needed.
# Out:
# Performing GridSearchCV for Logistic Regression
# Best parameters for Logistic Regression: {'C': 0.1}
# Best cross-validation score for Logistic Regression: 0.7977248104008667
#
# Performing GridSearchCV for Random Forest
# Best parameters for Random Forest: {'max_depth': 10, 'n_estimators': 57}
# Best cross-validation score for Random Forest: 0.8188318723529993

# %% [markdown]
# #Neural Network

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam


# Define your neural network architecture
model = Sequential([
    # Input layer
    Dense(units=64, activation='relu',),

    Dense(units=256, activation='relu'),
    # # Batch normalization layer
    BatchNormalization(),
    # # Dropout layer
    Dropout(0.5),



    # Hidden layers
    Dense(units=128, activation='relu'),
    #BatchNormalization(),
    Dropout(0.5),

    Dense(units=64, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    # Output layer
    Dense(units=1, activation='sigmoid')
])

optimizer = Adam(learning_rate=0.001)

# Compile the model
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

#
epoch_number = 27
history = model.fit(X_train, y_train, epochs=epoch_number, validation_split=0.4)

# Print the model summary
model.summary()
# Out:
# Epoch 1/27
# 14/14 [==============================] - 2s 15ms/step - loss: 0.9543 - accuracy: 0.5246 - val_loss: 0.6663 - val_accuracy: 0.6105
# Epoch 2/27
# 14/14 [==============================] - 0s 5ms/step - loss: 0.7560 - accuracy: 0.6323 - val_loss: 0.6459 - val_accuracy: 0.6035
# Epoch 3/27
# 14/14 [==============================] - 0s 5ms/step - loss: 0.7686 - accuracy: 0.6838 - val_loss: 0.6396 - val_accuracy: 0.6035
# Epoch 4/27
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6139 - accuracy: 0.7073 - val_loss: 0.6373 - val_accuracy: 0.6035
# Epoch 5/27
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6429 - accuracy: 0.7143 - val_loss: 0.6381 - val_accuracy: 0.6000
# Epoch 6/27
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6685 - accuracy: 0.7096 - val_loss: 0.6391 - val_accuracy: 0.6000
# Epoch 7/27
# ...

# %%
# Evaluate the model on the testing data
loss, accuracy = model.evaluate(X_test, y_test)

print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4181 - accuracy: 0.8436
# Test Loss: 0.41808775067329407
# Test Accuracy: 0.8435754179954529

# %%
loss, accuracy = model.evaluate(X_train, y_train)

print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3975 - accuracy: 0.8371
# Test Loss: 0.3974798023700714
# Test Accuracy: 0.8370786309242249
